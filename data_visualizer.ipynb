# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv',header=None)

# %%
malignant=df[df[1]=='M']
benign=df[df[1]=='B']

# %%
sns.relplot(data=df,x=2,y=3,hue=1,marker="x")
